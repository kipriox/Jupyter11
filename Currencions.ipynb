# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="30.03.2022" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>64,5838</Value></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>50,8872</Value></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>113,3603</Value></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>17,6948</Value></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,2566</Value></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>49,0447</Value></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>18,1148</Value></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>26,0548</Value></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>11,0252</Value></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>12,9075</Value></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>86,2843</Value></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>96,0085</Value></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>11,3551</Value></Valute><Valute ID="R01335"><NumCode>398</NumCode><CharCode>KZT</CharCode><Nominal>100</Nominal><Name>\xca\xe0\xe7\xe0\xf5\xf1\xf2\xe0\xed\xf1\xea\xe8\xf5 \xf2\xe5\xed\xe3\xe5</Name><Value>18,4763</Value></Valute><Valute ID="R01350"><NumCode>124</NumCode><CharCode>CAD</CharCode><Nominal>1</Nominal><Name>\xca\xe0\xed\xe0\xe4\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>68,9557</Value></Valute><Valute ID="R01370"><NumCode>417</NumCode><CharCode>KGS</CharCode><Nominal>100</Nominal><Name>\xca\xe8\xf0\xe3\xe8\xe7\xf1\xea\xe8\xf5 \xf1\xee\xec\xee\xe2</Name><Value>90,3741</Value></Valute><Valute ID="R01375"><NumCode>156</NumCode><CharCode>CNY</CharCode><Nominal>1</Nominal><Name>\xca\xe8\xf2\xe0\xe9\xf1\xea\xe8\xe9 \xfe\xe0\xed\xfc</Name><Value>13,5550</Value></Valute><Valute ID="R01500"><NumCode>498</NumCode><CharCode>MDL</CharCode><Nominal>10</Nominal><Name>\xcc\xee\xeb\xe4\xe0\xe2\xf1\xea\xe8\xf5 \xeb\xe5\xe5\xe2</Name><Value>47,1370</Value></Valute><Valute ID="R01535"><NumCode>578</NumCode><CharCode>NOK</CharCode><Nominal>10</Nominal><Name>\xcd\xee\xf0\xe2\xe5\xe6\xf1\xea\xe8\xf5 \xea\xf0\xee\xed</Name><Value>99,7529</Value></Valute><Valute ID="R01565"><NumCode>985</NumCode><CharCode>PLN</CharCode><Nominal>1</Nominal><Name>\xcf\xee\xeb\xfc\xf1\xea\xe8\xe9 \xe7\xeb\xee\xf2\xfb\xe9</Name><Value>20,6412</Value></Valute><Valute ID=" ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# OrderedDict([('ValCurs',
#               OrderedDict([('@Date', '30.03.2022'),
#                            ('@name', 'Foreign Currency Market'),
#                            ('Valute',
#                             [OrderedDict([('@ID', 'R01010'),
#                                           ('NumCode', '036'),
#                                           ('CharCode', 'AUD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Австралийский доллар'),
#                                           ('Value', '64,5838')]),
#                              OrderedDict([('@ID', 'R01020A'),
#                                           ('NumCode', '944'),
#                                           ('CharCode', 'AZN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Азербайджанский манат'),
#                                           ('Value', '50,8872')]),
#                              OrderedDict([('@ID', 'R01035'),
#                                           ('NumCode', '826'),
#                                           ('CharCode', 'GBP'),
#                                           ('Nominal', '1'),
#                                           ('Name',
#                                            'Фунт стерлингов Соединенного королевства'),
#                                           ('Value', '113,3603')]),
#                              OrderedDict([('@ID', 'R01060'),
#                                           ('NumCode', '051'),
#                                           ('CharCode', 'AMD'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Армянских драмов'),
#                                           ('Value', '17,6948')]),
#                              OrderedDict([('@ID', 'R01090B'),
#                                           ('NumCode', '933'),
#                                           ('CharCode', 'BYN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Белорусский рубль'),
#                                           ('Value', '28,2566')]),
#                              OrderedDict([('@ID', 'R01100'),
#                                           ('NumCode', '975'),
#                                           ('CharCode', 'BGN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Болгарский лев'),
#                                           ('Value', '49,0447')]),
#                              OrderedDict([('@ID', 'R01115'),
#                                           ('NumCode', '986'),
#                                           ('CharCode', 'BRL'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Бразильский реал'),
#                                           ('Value', '18,1148')]),
#                              OrderedDict([('@ID', 'R01135'),
#                                           ('NumCode', '348'),
#                                           ('CharCode', 'HUF'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Венгерских форинтов'),
#                                           ('Value', '26,0548')]),
#                              OrderedDict([('@ID', 'R01200'),
#                                           ('NumCode', '344'),
#                                           ('CharCode', 'HKD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Гонконгский доллар'),
#                                           ('Value', '11,0252')]),
#                              OrderedDict([('@ID', 'R01215'),
#                                           ('NumCode', '208'),
#                                           ('CharCode', 'DKK'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Датская крона'),
#                                           ('Value', '12,9075')]),
#                              OrderedDict([('@ID', 'R01235'),
#                                           ('NumCode', '840'),
#                                           ('CharCode', 'USD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Доллар США'),
#                                           ('Value', '86,2843')]),
#                              OrderedDict([('@ID', 'R01239'),
#                                           ('NumCode', '978'),
#                                           ('CharCode', 'EUR'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Евро'),
#                                           ('Value', '96,0085')]),
#                              OrderedDict([('@ID', 'R01270'),
#                                           ('NumCode', '356'),
#                                           ('CharCode', 'INR'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Индийских рупий'),
#                                           ('Value', '11,3551')]),
#                              OrderedDict([('@ID', 'R01335'),
#                                           ('NumCode', '398'),
#                                           ('CharCode', 'KZT'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Казахстанских тенге'),
#                                           ('Value', '18,4763')]),
#                              OrderedDict([('@ID', 'R01350'),
#                                           ('NumCode', '124'),
#                                           ('CharCode', 'CAD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Канадский доллар'),
#                                           ('Value', '68,9557')]),
#                              OrderedDict([('@ID', 'R01370'),
#                                           ('NumCode', '417'),
#                                           ('CharCode', 'KGS'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Киргизских сомов'),
#                                           ('Value', '90,3741')]),
#                              OrderedDict([('@ID', 'R01375'),
#                                           ('NumCode', '156'),
#                                           ('CharCode', 'CNY'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Китайский юань'),
#                                           ('Value', '13,5550')]),
#                              OrderedDict([('@ID', 'R01500'),
#                                           ('NumCode', '498'),
#                                           ('CharCode', 'MDL'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Молдавских леев'),
#                                           ('Value', '47,1370')]),
#                              OrderedDict([('@ID', 'R01535'),
#                                           ('NumCode', '578'),
#                                           ('CharCode', 'NOK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Норвежских крон'),
#                                           ('Value', '99,7529')]),
#                              OrderedDict([('@ID', 'R01565'),
#                                           ('NumCode', '985'),
#                                           ('CharCode', 'PLN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Польский злотый'),
#                                           ('Value', '20,6412')]),
#                              OrderedDict([('@ID', 'R01585F'),
#                                           ('NumCode', '946'),
#                                           ('CharCode', 'RON'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Румынский лей'),
#                                           ('Value', '19,4080')]),
#                              OrderedDict([('@ID', 'R01589'),
#                                           ('NumCode', '960'),
#                                           ('CharCode', 'XDR'),
#                                           ('Nominal', '1'),
#                                           ('Name',
#                                            'СДР (специальные права заимствования)'),
#                                           ('Value', '118,9006')]),
#                              OrderedDict([('@ID', 'R01625'),
#                                           ('NumCode', '702'),
#                                           ('CharCode', 'SGD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Сингапурский доллар'),
#                                           ('Value', '63,6221')]),
#                              OrderedDict([('@ID', 'R01670'),
#                                           ('NumCode', '972'),
#                                           ('CharCode', 'TJS'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Таджикских сомони'),
#                                           ('Value', '71,3205')]),
#                              OrderedDict([('@ID', 'R01700J'),
#                                           ('NumCode', '949'),
#                                           ('CharCode', 'TRY'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Турецких лир'),
#                                           ('Value', '59,1568')]),
#                              OrderedDict([('@ID', 'R01710A'),
#                                           ('NumCode', '934'),
#                                           ('CharCode', 'TMT'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Новый туркменский манат'),
#                                           ('Value', '24,6527')]),
#                              OrderedDict([('@ID', 'R01717'),
#                                           ('NumCode', '860'),
#                                           ('CharCode', 'UZS'),
#                                           ('Nominal', '10000'),
#                                           ('Name', 'Узбекских сумов'),
#                                           ('Value', '75,2379')]),
#                              OrderedDict([('@ID', 'R01720'),
#                                           ('NumCode', '980'),
#                                           ('CharCode', 'UAH'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Украинских гривен'),
#                                           ('Value', '29,2355')]),
#                              OrderedDict([('@ID', 'R01760'),
#                                           ('NumCode', '203'),
#                                           ('CharCode', 'CZK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Чешских крон'),
#                                           ('Value', '39,2073')]),
#                              OrderedDict([('@ID', 'R01770'),
#                                           ('NumCode', '752'),
#                                           ('CharCode', 'SEK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Шведских крон'),
#                                           ('Value', '93,0399')]),
#                              OrderedDict([('@ID', 'R01775'),
#                                           ('NumCode', '756'),
#                                           ('CharCode', 'CHF'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Швейцарский франк'),
#                                           ('Value', '92,5301')]),
#                              OrderedDict([('@ID', 'R01810'),
#                                           ('NumCode', '710'),
#                                           ('CharCode', 'ZAR'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Южноафриканских рэндов'),
#                                           ('Value', '59,3623')]),
#                              OrderedDict([('@ID', 'R01815'),
#                                           ('NumCode', '410'),
#                                           ('CharCode', 'KRW'),
#                                           ('Nominal', '1000'),
#                                           ('Name', 'Вон Республики Корея'),
#                                           ('Value', '70,7480')]),
#                              OrderedDict([('@ID', 'R01820'),
#                                           ('NumCode', '392'),
#                                           ('CharCode', 'JPY'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Японских иен'),
#                                           ('Value', '70,2898')])])]))])

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [OrderedDict([('@ID', 'R01010'),
#               ('NumCode', '036'),
#               ('CharCode', 'AUD'),
#               ('Nominal', '1'),
#               ('Name', 'Австралийский доллар'),
#               ('Value', '64,5838')]),
#  OrderedDict([('@ID', 'R01020A'),
#               ('NumCode', '944'),
#               ('CharCode', 'AZN'),
#               ('Nominal', '1'),
#               ('Name', 'Азербайджанский манат'),
#               ('Value', '50,8872')]),
#  OrderedDict([('@ID', 'R01035'),
#               ('NumCode', '826'),
#               ('CharCode', 'GBP'),
#               ('Nominal', '1'),
#               ('Name', 'Фунт стерлингов Соединенного королевства'),
#               ('Value', '113,3603')]),
#  OrderedDict([('@ID', 'R01060'),
#               ('NumCode', '051'),
#               ('CharCode', 'AMD'),
#               ('Nominal', '100'),
#               ('Name', 'Армянских драмов'),
#               ('Value', '17,6948')]),
#  OrderedDict([('@ID', 'R01090B'),
#               ('NumCode', '933'),
#               ('CharCode', 'BYN'),
#               ('Nominal', '1'),
#               ('Name', 'Белорусский рубль'),
#               ('Value', '28,2566')]),
#  OrderedDict([('@ID', 'R01100'),
#               ('NumCode', '975'),
#               ('CharCode', 'BGN'),
#               ('Nominal', '1'),
#               ('Name', 'Болгарский лев'),
#               ('Value', '49,0447')]),
#  OrderedDict([('@ID', 'R01115'),
#               ('NumCode', '986'),
#               ('CharCode', 'BRL'),
#               ('Nominal', '1'),
#               ('Name', 'Бразильский реал'),
#               ('Value', '18,1148')]),
#  OrderedDict([('@ID', 'R01135'),
#               ('NumCode', '348'),
#               ('CharCode', 'HUF'),
#               ('Nominal', '100'),
#               ('Name', 'Венгерских форинтов'),
#               ('Value', '26,0548')]),
#  OrderedDict([('@ID', 'R01200'),
#               ('NumCode', '344'),
#               ('CharCode', 'HKD'),
#               ('Nominal', '1'),
#               ('Name', 'Гонконгский доллар'),
#               ('Value', '11,0252')]),
#  OrderedDict([('@ID', 'R01215'),
#               ('NumCode', '208'),
#               ('CharCode', 'DKK'),
#               ('Nominal', '1'),
#               ('Name', 'Датская крона'),
#               ('Value', '12,9075')]),
#  OrderedDict([('@ID', 'R01235'),
#               ('NumCode', '840'),
#               ('CharCode', 'USD'),
#               ('Nominal', '1'),
#               ('Name', 'Доллар США'),
#               ('Value', '86,2843')]),
#  OrderedDict([('@ID', 'R01239'),
#               ('NumCode', '978'),
#               ('CharCode', 'EUR'),
#               ('Nominal', '1'),
#               ('Name', 'Евро'),
#               ('Value', '96,0085')]),
#  OrderedDict([('@ID', 'R01270'),
#               ('NumCode', '356'),
#               ('CharCode', 'INR'),
#               ('Nominal', '10'),
#               ('Name', 'Индийских рупий'),
#               ('Value', '11,3551')]),
#  OrderedDict([('@ID', 'R01335'),
#               ('NumCode', '398'),
#               ('CharCode', 'KZT'),
#               ('Nominal', '100'),
#               ('Name', 'Казахстанских тенге'),
#               ('Value', '18,4763')]),
#  OrderedDict([('@ID', 'R01350'),
#               ('NumCode', '124'),
#               ('CharCode', 'CAD'),
#               ('Nominal', '1'),
#               ('Name', 'Канадский доллар'),
#               ('Value', '68,9557')]),
#  OrderedDict([('@ID', 'R01370'),
#               ('NumCode', '417'),
#               ('CharCode', 'KGS'),
#               ('Nominal', '100'),
#               ('Name', 'Киргизских сомов'),
#               ('Value', '90,3741')]),
#  OrderedDict([('@ID', 'R01375'),
#               ('NumCode', '156'),
#               ('CharCode', 'CNY'),
#               ('Nominal', '1'),
#               ('Name', 'Китайский юань'),
#               ('Value', '13,5550')]),
#  OrderedDict([('@ID', 'R01500'),
#               ('NumCode', '498'),
#               ('CharCode', 'MDL'),
#               ('Nominal', '10'),
#               ('Name', 'Молдавских леев'),
#               ('Value', '47,1370')]),
#  OrderedDict([('@ID', 'R01535'),
#               ('NumCode', '578'),
#               ('CharCode', 'NOK'),
#               ('Nominal', '10'),
#               ('Name', 'Норвежских крон'),
#               ('Value', '99,7529')]),
#  OrderedDict([('@ID', 'R01565'),
#               ('NumCode', '985'),
#               ('CharCode', 'PLN'),
#               ('Nominal', '1'),
#               ('Name', 'Польский злотый'),
#               ('Value', '20,6412')]),
#  OrderedDict([('@ID', 'R01585F'),
#               ('NumCode', '946'),
#               ('CharCode', 'RON'),
#               ('Nominal', '1'),
#               ('Name', 'Румынский лей'),
#               ('Value', '19,4080')]),
#  OrderedDict([('@ID', 'R01589'),
#               ('NumCode', '960'),
#               ('CharCode', 'XDR'),
#               ('Nominal', '1'),
#               ('Name', 'СДР (специальные права заимствования)'),
#               ('Value', '118,9006')]),
#  OrderedDict([('@ID', 'R01625'),
#               ('NumCode', '702'),
#               ('CharCode', 'SGD'),
#               ('Nominal', '1'),
#               ('Name', 'Сингапурский доллар'),
#               ('Value', '63,6221')]),
#  OrderedDict([('@ID', 'R01670'),
#               ('NumCode', '972'),
#               ('CharCode', 'TJS'),
#               ('Nominal', '10'),
#               ('Name', 'Таджикских сомони'),
#               ('Value', '71,3205')]),
#  OrderedDict([('@ID', 'R01700J'),
#               ('NumCode', '949'),
#               ('CharCode', 'TRY'),
#               ('Nominal', '10'),
#               ('Name', 'Турецких лир'),
#               ('Value', '59,1568')]),
#  OrderedDict([('@ID', 'R01710A'),
#               ('NumCode', '934'),
#               ('CharCode', 'TMT'),
#               ('Nominal', '1'),
#               ('Name', 'Новый туркменский манат'),
#               ('Value', '24,6527')]),
#  OrderedDict([('@ID', 'R01717'),
#               ('NumCode', '860'),
#               ('CharCode', 'UZS'),
#               ('Nominal', '10000'),
#               ('Name', 'Узбекских сумов'),
#               ('Value', '75,2379')]),
#  OrderedDict([('@ID', 'R01720'),
#               ('NumCode', '980'),
#               ('CharCode', 'UAH'),
#               ('Nominal', '10'),
#               ('Name', 'Украинских гривен'),
#               ('Value', '29,2355')]),
#  OrderedDict([('@ID', 'R01760'),
#               ('NumCode', '203'),
#               ('CharCode', 'CZK'),
#               ('Nominal', '10'),
#               ('Name', 'Чешских крон'),
#               ('Value', '39,2073')]),
#  OrderedDict([('@ID', 'R01770'),
#               ('NumCode', '752'),
#               ('CharCode', 'SEK'),
#               ('Nominal', '10'),
#               ('Name', 'Шведских крон'),
#               ('Value', '93,0399')]),
#  OrderedDict([('@ID', 'R01775'),
#               ('NumCode', '756'),
#               ('CharCode', 'CHF'),
#               ('Nominal', '1'),
#               ('Name', 'Швейцарский франк'),
#               ('Value', '92,5301')]),
#  OrderedDict([('@ID', 'R01810'),
#               ('NumCode', '710'),
#               ('CharCode', 'ZAR'),
#               ('Nominal', '10'),
#               ('Name', 'Южноафриканских рэндов'),
#               ('Value', '59,3623')]),
#  OrderedDict([('@ID', 'R01815'),
#               ('NumCode', '410'),
#               ('CharCode', 'KRW'),
#               ('Nominal', '1000'),
#               ('Name', 'Вон Республики Корея'),
#               ('Value', '70,7480')]),
#  OrderedDict([('@ID', 'R01820'),
#               ('NumCode', '392'),
#               ('CharCode', 'JPY'),
#               ('Nominal', '100'),
#               ('Name', 'Японских иен'),
#               ('Value', '70,2898')])]

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '64,5838']
# ['AZN', 'Азербайджанский манат', '50,8872']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '113,3603']
# ['AMD', 'Армянских драмов', '17,6948']
# ['BYN', 'Белорусский рубль', '28,2566']
# ['BGN', 'Болгарский лев', '49,0447']
# ['BRL', 'Бразильский реал', '18,1148']
# ['HUF', 'Венгерских форинтов', '26,0548']
# ['HKD', 'Гонконгский доллар', '11,0252']
# ['DKK', 'Датская крона', '12,9075']
# ['USD', 'Доллар США', '86,2843']
# ['EUR', 'Евро', '96,0085']
# ['INR', 'Индийских рупий', '11,3551']
# ['KZT', 'Казахстанских тенге', '18,4763']
# ['CAD', 'Канадский доллар', '68,9557']
# ['KGS', 'Киргизских сомов', '90,3741']
# ['CNY', 'Китайский юань', '13,5550']
# ['MDL', 'Молдавских леев', '47,1370']
# ['NOK', 'Норвежских крон', '99,7529']
# ['PLN', 'Польский злотый', '20,6412']
# ['RON', 'Румынский лей', '19,4080']
# ['XDR', 'СДР (специальные права заимствования)', '118,9006']
# ['SGD', 'Сингапурский доллар', '63,6221']
# ['TJS', 'Таджикских сомони', '71,3205']
# ['TRY', 'Турецких лир', '59,1568']
# ['TMT', 'Новый туркменский манат', '24,6527']
# ['UZS', 'Узбекских сумов', '75,2379']
# ['UAH', 'Украинских гривен', '29,2355']
# ['CZK', 'Чешских крон', '39,2073']
# ['SEK', 'Шведских крон', '93,0399']
# ['CHF', 'Швейцарский франк', '92,5301']
# ['ZAR', 'Южноафриканских рэндов', '59,3623']
# ['KRW', 'Вон Республики Корея', '70,7480']
# ['JPY', 'Японских иен', '70,2898']
